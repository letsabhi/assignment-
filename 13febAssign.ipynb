# %% [markdown]
# ### Q1. Explain why we have to use the Exception class while creating a Custom Exception. Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# #### We use exception class for defining the custom exception because its use for inhering function of the epception class. Here, we have overridden the constructor of the Exception class to accept our own custom arguments

# %% [markdown]
# ### Q2. Write a python program to print Python Exception Hierarchy.

# %%
import inspect
print("The class hierarchy for built-in exceptions is:")
inspect.getclasstree(inspect.getmro(Exception))
def classtree(cls, indent=0):
    print('.' * indent, cls.__name__)
    for subcls in cls.__subclasses__():
        classtree(subcls, indent + 3)
classtree(Exception)
# Out:
# The class hierarchy for built-in exceptions is:
#  Exception
# ... TypeError
# ...... FloatOperation
# ...... MultipartConversionError
# ... StopAsyncIteration
# ... StopIteration
# ... ImportError
# ...... ModuleNotFoundError
# ...... ZipImportError
# ... OSError
# ...... ConnectionError
# ......... BrokenPipeError
# ......... ConnectionAbortedError
# ......... ConnectionRefusedError
# ......... ConnectionResetError
# ............ RemoteDisconnected
# ...... BlockingIOError
# ...... ChildProcessError
# ...... FileExistsError
# ...... FileNotFoundError
# ...... IsADirectoryError
# ...... NotADirectoryError
# ...... InterruptedError
# ......... InterruptedSystemCall
# ...... PermissionError
# ...... ProcessLookupError
# ...... TimeoutError
# ...... UnsupportedOperation
# ...... itimer_error
# ...... herror
# ...... gaierror
# ...... SSLError
# ......... SSLCertVerificationError
# ......... SSLZeroReturnError
# ......... SSLWantWriteError
# ......... SSLWantReadError
# ...

# %% [markdown]
# #### Q3  What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# #### The errors defined in the ArithmeticError clss is
#     * OverFlowError
#     * ZeroDivisionError
#     * FloatingPointError

# %%
try:
  arithmetic = 5/0
  print(arithmetic)
except ArithmeticError as e:
  print('You have just made an Arithmetic error',e)

# %%
try:
    print("Simple program for showing overflow error")
    print("\n")
    import math
    print("The exponential value is")
    print(math.exp(1000))
except ArithmeticError as e: 
  print('You have just made an Arithmetic error',e)
# Out:
# Simple program for showing overflow error
#
#
# The exponential value is
# You have just made an Arithmetic error math range error

# %% [markdown]
# #### Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
list = [1,2,3,4,5,6]
try:
   print(list[10])
except Exception as e:
   print("Array index out of bound",e)
# Out:
# Array index out of bound list index out of range

# %%
dict = {'name':'Abhhishek', 'job':'Ace Engineering Academy', 'sex':'male', 'wife':'Smita'}

# %%
dict
# Out:
# {'name': 'Abhhishek',
#  'job': 'Ace Engineering Academy',
#  'sex': 'male',
#  'wife': 'Smita'}

# %%
try:
    print(dict[son])
except Exception as e:
 print("We got an error:", e)
# Out:
# We got an error: name 'son' is not defined

# %% [markdown]
# #### Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# #### ImportError is raised when a module, or member of a module, cannot be imported. There are a two conditions where an ImportError might be raised. If a module does not exist.

# %%
import sys
try:
    from exception import myexception
except Exception as e:
    print("The Error is",e)
# Out:
# The Error is No module named 'exception'

# %% [markdown]
# #### Q6  List down some best practices for exception handling in python.

# %%
### use very specific Exception
### Print Always specefic messages  
### Dont write multiple exception handeling
### Do proper Documentation 
### cleanuo all the resources

# %%
X = int(input("Enter a Number")) 
R = X*X print "Square=",R
# Out:
#   Cell In[1], line 2
#     R = X*X print "Square=",R
#             ^
# SyntaxError: invalid syntax
